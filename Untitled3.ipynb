# %%
# %matplotlib widget
import matplotlib
from matplotlib import pyplot as plt
with plt.ioff():
    fig = plt.figure()
plt.plot([0,1],[0,1])
fig.savefig('test.png')
display(fig)
print(f'Matplotlib version: {matplotlib.__version__}')
print(fig.canvas._is_saving) # no attribute error!!
# Out:
# Matplotlib version: 3.3.1.post929+g2c265edcd
# False

# %%
fig.canvas._is_saving

# %%
display(fig)
